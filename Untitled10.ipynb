# %%
a = "sud'h"

# %%
a
# Out:
# "sud'h"

# %%
 b = 'aman"S'

# %%
b
# Out:
# 'aman"S'

# %%
c = 'this is my first class for full stack data sccience, that"s why i join this '

# %%
c
# Out:
# 'this is my first class for full stack data sccience, that"s why i join this '

# %%
s = "This is s full stack class"

# %%
s
# Out:
# 'This is s full stack class'

# %%
s[0]
# Out:
# 'T'

# %%
s[-1]
# Out:
# 's'

# %%
s[16]
# Out:
# 't'

# %%
s[12:3]
# Out:
# ''

# %%
s[12:16]
# Out:
# 'll s'

# %%
s[16:12:-1]
# Out:
# 'ts l'

# %%
s[2:4]
# Out:
# 'is'

# %%
s[4:2:-1]
# Out:
# ' s'

# %%
s[4: 1: -1]
# Out:
# ' si'

# %%
a = "aman"

# %%
a[1:3]
# Out:
# 'ma'

# %%
a[3:1:-1]
# Out:
# 'na'

# %%
a[2:0:-1]
# Out:
# 'am'

# %%
s[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 s[100]
#
# IndexError: string index out of range

# %%
len(s)
# Out:
# 26

# %%
s[26]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 s[26]
#
# IndexError: string index out of range

# %%
s[25]
# Out:
# 's'

# %%
s[3:20]
# Out:
# 's is s full stack'

# %%
s[-1:-20:-1]
# Out:
# 'ssalc kcats lluf s '

# %%
s[-1:-19:-1]
# Out:
# 'ssalc kcats lluf s'

# %%
s
# Out:
# 'This is s full stack class'

# %%
for i in s:
    print(i, end= "")
# Out:
# This is s full stack class

# %%
for i in range(len(s), 0, -1):
    print(s[i-1], end = "")
# Out:
# ssalc kcats lluf s si sihT

# %%
s[::-1]
# Out:
# 'ssalc kcats lluf s si sihT'

# %%
s[::1]
# Out:
# 'This is s full stack class'

# %%
s
# Out:
# 'This is s full stack class'

# %%
s[0] = "M"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 s[0] = "M"
#
# TypeError: 'str' object does not support item assignment

# %%
s[0]
# Out:
# 'T'

# %%
l= ["dgfgd", 762, 3278, "jhshd", True]

# %%
l
# Out:
# ['dgfgd', 762, 3278, 'jhshd', True]

# %%
l[0]
# Out:
# 'dgfgd'

# %%
l[0] = "aman"

# %%
l
# Out:
# ['aman', 762, 3278, 'jhshd', True]

# %%
l
# Out:
# ['aman', 762, 3278, 'jhshd', True]

# %%
s = "jhasghgs"

# %%
s[0] = "M"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 s[0] = "M"
#
# TypeError: 'str' object does not support item assignment

# %%
l= ["dgfgd", 762, 3278, "jhshd", True, [65,"hjghsfg", "h", 8765]]

# %%
l
# Out:
# ['dgfgd', 762, 3278, 'jhshd', True, [65, 'hjghsfg', 'h', 8765]]

# %%
l[5]
# Out:
# [65, 'hjghsfg', 'h', 8765]

# %%
l
# Out:
# ['dgfgd', 762, 3278, 'jhshd', True, [65, 'hjghsfg', 'h', 8765]]

# %%
l[::-1]
# Out:
# [[65, 'hjghsfg', 'h', 8765], True, 'jhshd', 3278, 762, 'dgfgd']

# %%
for i in l:
    print(i)
# Out:
# dgfgd
# 762
# 3278
# jhshd
# True
# [65, 'hjghsfg', 'h', 8765]

# %%
for i in l:
    print(type(i))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'bool'>
# <class 'list'>

# %%
type(l[0])
# Out:
# str

# %%
type(l)
# Out:
# list

# %%
"sudh" + " kumar"
# Out:
# 'sudh kumar'

# %%
"aman" + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 "aman" + 2
#
# TypeError: can only concatenate str (not "int") to str

# %%
"aman" + str(2)
# Out:
# 'aman2'

# %%
"aman " *76
# Out:
# 'aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman aman '

# %%
s = "my name is "

# %%
s
# Out:
# 'my name is '

# %%
s.find("i")
# Out:
# 8

# %%
s.find(" ")
# Out:
# 2

# %%
s.find(" ", -1)
# Out:
# 10

# %%
s.find("m",-1)
# Out:
# -1

# %%
s.find("m")
# Out:
# 0

# %%
s.find("my")
# Out:
# 0

# %%
s.find("name")
# Out:
# 3

# %%
s
# Out:
# 'my name is '

# %%
s.index("name")
# Out:
# 3

# %%
s = "my name is sudhanshu kumar , Name of org is ineoron"

# %%
s.find("name")
# Out:
# 3

# %%
s.find("name", -1)
# Out:
# -1

# %%
s
# Out:
# 'my name is sudhanshu kumar , name of org is ineoron'

# %%
s.find("n")
# Out:
# 3

# %%
s.find("name")
# Out:
# 3

# %%
b = s.find("name")
for i in range(len("name")):
    print(b+i)
# Out:
# 3
# 4
# 5
# 6

# %%
s.count("m")
# Out:
# 4

# %%
s.count("name")
# Out:
# 1

# %%
s.count
# Out:
# <function str.count>

# %%
s.split()
# Out:
# ['my',
#  'name',
#  'is',
#  'sudhanshu',
#  'kumar',
#  ',',
#  'Name',
#  'of',
#  'org',
#  'is',
#  'ineoron']

# %%
s.split(',')
# Out:
# ['my name is sudhanshu kumar ', ' Name of org is ineoron']

# %%
s.split("n")
# Out:
# ['my ', 'ame is sudha', 'shu kumar , Name of org is i', 'eoro', '']

# %%
s.split('na')
# Out:
# ['my ', 'me is sudhanshu kumar , Name of org is ineoron']

# %%
s.split()
# Out:
# ['my',
#  'name',
#  'is',
#  'sudhanshu',
#  'kumar',
#  ',',
#  'Name',
#  'of',
#  'org',
#  'is',
#  'ineoron']

# %%
type(s.split())
# Out:
# list

# %%
s.upper()
# Out:
# 'MY NAME IS SUDHANSHU KUMAR , NAME OF ORG IS INEORON'

# %%
s.lower()
# Out:
# 'my name is sudhanshu kumar , name of org is ineoron'

# %%
s.lower()
# Out:
# 'my name is sudhanshu kumar , name of org is ineoron'

# %%
s.count('n')
# Out:
# 4

# %%
s.swapcase()
# Out:
# 'MY NAME IS SUDHANSHU KUMAR , nAME OF ORG IS INEORON'

# %%
s = s.swapcase()

# %%
s
# Out:
# 'MY NAME IS SUDHANSHU KUMAR , nAME OF ORG IS INEORON'

# %%
s.upper
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[150], line 1
# ----> 1 s.upper
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'upper'

# %%
s
# Out:
# <function str.upper()>

# %%
s
# Out:
# <function str.upper()>

# %%
s = "my name is sudhanshu kumar , name of org is ineoron"

# %%
ss
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[153], line 1
# ----> 1 ss
#
# NameError: name 'ss' is not defined

# %%
s
# Out:
# 'my name is sudhanshu kumar , name of org is ineoron'

# %%
s.split()
# Out:
# ['my',
#  'name',
#  'is',
#  'sudhanshu',
#  'kumar',
#  ',',
#  'name',
#  'of',
#  'org',
#  'is',
#  'ineoron']

# %%
s.upper()
# Out:
# 'MY NAME IS SUDHANSHU KUMAR , NAME OF ORG IS INEORON'

# %%
s.lower()
# Out:
# 'my name is sudhanshu kumar , name of org is ineoron'

# %%
s.count("a")
# Out:
# 4

# %%
s.count("m")
# Out:
# 4

# %%
s.count("name")
# Out:
# 2

# %%
s.find("a")
# Out:
# 4

# %%
" ".join(s)
# Out:
# 'm y   n a m e   i s   s u d h a n s h u   k u m a r   ,   n a m e   o f   o r g   i s   i n e o r o n'

# %%
reversed(s)

# %%
s[::-1]
# Out:
# 'noroeni si gro fo eman , ramuk uhsnahdus si eman ym'

# %%
s
# Out:
# 'my name is sudhanshu kumar , name of org is ineoron'

# %%
s[::]
# Out:
# 'my name is sudhanshu kumar , name of org is ineoron'

# %%
s[::-1]
# Out:
# 'noroeni si gro fo eman , ramuk uhsnahdus si eman ym'

# %%
list(reversed(s))
# Out:
# ['n',
#  'o',
#  'r',
#  'o',
#  'e',
#  'n',
#  'i',
#  ' ',
#  's',
#  'i',
#  ' ',
#  'g',
#  'r',
#  'o',
#  ' ',
#  'f',
#  'o',
#  ' ',
#  'e',
#  'm',
#  'a',
#  'n',
#  ' ',
#  ',',
#  ' ',
#  'r',
#  'a',
#  'm',
#  'u',
#  'k',
#  ' ',
#  'u',
#  'h',
#  's',
#  'n',
#  'a',
#  'h',
#  'd',
#  'u',
#  's',
#  ' ',
#  's',
#  'i',
#  ' ',
#  'e',
#  'm',
#  'a',
#  'n',
#  ' ',
#  'y',
#  'm']

# %%
l1 = ["shghds", 67325, "jhsduyg", 9878.7657, 2+7j]

# %%
l1
# Out:
# ['shghds', 67325, 'jhsduyg', 9878.7657, (2+7j)]

# %%
for i in reversed(s):
    print(i)
# Out:
# n
# o
# r
# o
# e
# n
# i
#
# s
# i
#
# g
# r
# o
#
# f
# o
#
# e
# m
# a
# n
#
# ,
#
# r
# a
# m
# u
# k
#
# u
# h
# s
# n
# a
# h
# d
# u
# s
#
# s
# i
#
# e
# m
# a
# n
#
# y
# m

# %%
reversed(s)

# %%
for i in reversed(s):
    print(i, end = "")
# Out:
# noroeni si gro fo eman , ramuk uhsnahdus si eman ym

# %%
type(reversed(s))
# Out:
# reversed

# %%
type(s)
# Out:
# str

# %%
s = "    sm   sn   "

# %%
s.strip()
# Out:
# 'sm   sn'

# %%
reversed(s)

# %%
s[::-1]
# Out:
# '   ns   ms    '

# %%
s.lstrip()
# Out:
# 'sm   sn   '

# %%
s.rstrip()
# Out:
# '    sm   sn'

# %%
s = "Greetin from ineoeon"

# %%
s = s.replace("G", "s")

# %%
s
# Out:
# 'sreetin from ineoeon'

# %%
l2 = ["hdsj", 32654, "djkh"]
l2[2]
# Out:
# 'djkh'

# %%
l2[2] = "aman"

# %%
l2
# Out:
# ['hdsj', 32654, 'aman']

# %%
s = "aman"

# %%
s[0]
# Out:
# 'a'

# %%
s[0] = "s"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[201], line 1
# ----> 1 s[0] = "s"
#
# TypeError: 'str' object does not support item assignment

# %%
s.strip()
# Out:
# 'aman'

# %%
s
# Out:
# 'aman'

# %%
s = "SUDH"

# %%
s.lower()
# Out:
# 'sudh'

# %%
s.center(20, '-')
# Out:
# '--------SUDH--------'

# %%
s = "sudh\tkum\tar"

# %%
s
# Out:
# 'sudh\tkum\tar'

# %%
s.expandtabs()
# Out:
# 'sudh    kum     ar'

# %%
a = "we all are a part of full stack"

# %%
a.split()
# Out:
# ['we', 'all', 'are', 'a', 'part', 'of', 'full', 'stack']

# %%
a.lower()
# Out:
# 'we all are a part of full stack'

# %%
a.count("a")
# Out:
# 5

# %%
for i in range(len(a)):
    if a[i] == "a":
        print(i)
# Out:
# 3
# 7
# 11
# 14
# 28

# %%
a
# Out:
# 'we all are a part of full stack'

# %%
a[0]
# Out:
# 'w'

# %%
a.replace("a", "ineuron")
# Out:
# 'we ineuronll ineuronre ineuron pineuronrt of full stineuronck'

# %%
a
# Out:
# 'we all are a part of full stack'

# %%
a.split()
# Out:
# ['we', 'all', 'are', 'a', 'part', 'of', 'full', 'stack']

# %%
len(a)
# Out:
# 31

# %%
s = "sudh"

# %%
s.isupper()
# Out:
# False

# %%
s.islower()
# Out:
# True

# %%
s.lower()
# Out:
# 'sudh'

# %%
s.upper()
# Out:
# 'SUDH'

# %%
s.isupper()
# Out:
# False

# %%
s.islower()
# Out:
# True

# %%
s = "AMAN"

# %%
s.isupper()
# Out:
# True

# %%
s.isspace()
# Out:
# False

# %%
s = "     aman"

# %%
s.isspace()
# Out:
# False

# %%
s  = "  "

# %%
s.isspace()
# Out:
# True

# %%
s = "sudj81726"

# %%
s.isdigit()
# Out:
# False

# %%
s = "6545"

# %%
s.isdigit()
# Out:
# True

# %%
s = "sudhs"

# %%
s.endswith("s")
# Out:
# True

# %%
s.startswith("n")
# Out:
# False

# %%
s.startswith("s")
# Out:
# True

# %%
s.isalnum()
# Out:
# True

# %%
s.isalpha()
# Out:
# True

# %%
s = "6256shgh"

# %%
s.isalnum()
# Out:
# True

# %%
s.isalpha()
# Out:
# False

# %%
s.istitle()
# Out:
# False

# %%
s = "Aman"

# %%
s.istitle()
# Out:
# True

# %%
s = "This is a full stack batch"

# %%
len(s)
# Out:
# 26

# %%
for i in s:
    print(i)
# Out:
# T
# h
# i
# s
#
# i
# s
#
# a
#
# f
# u
# l
# l
#
# s
# t
# a
# c
# k
#
# b
# a
# t
# c
# h

# %%
count = 0
for i in s :
    count = count + 1
print(count)
# Out:
# 26

# %%
for i in s:
    print(i)
# Out:
# T
# h
# i
# s
#
# i
# s
#
# a
#
# f
# u
# l
# l
#
# s
# t
# a
# c
# k
#
# b
# a
# t
# c
# h

# %%
for i in range(1, len(s)+1):
    print(s[-i])
# Out:
# h
# c
# t
# a
# b
#
# k
# c
# a
# t
# s
#
# l
# l
# u
# f
#
# a
#
# s
# i
#
# s
# i
# h
# T

# %%
s = "sudh"
ch = len(s)-1
while ch>=0 :
    print(s[ch])
    ch = ch-1
# Out:
# h
# d
# u
# s

# %%
name = "iNeruon"
vowels = "AaEeIiOoUu"

# %%
for i in name:
    if i in vowels:
        print("{} is a vowel".format(i))
    else:
        print("{} is not a vowel".format(i))
# Out:
# i is a vowel
# N is not a vowel
# e is a vowel
# r is not a vowel
# u is a vowel
# o is a vowel
# n is not a vowel

# %%
"{} name is sudh".format("My")
# Out:
# 'My name is sudh'

# %%
"{} name is aman".format("my")
# Out:
# 'my name is aman'

# %%
"{} name {} aman".format("my", "is")
# Out:
# 'my name is aman'

# %%
a = input()
b = input()
c = input()
# Out:
#  aman
#  kumar
#  hero

# %%
"{} name {} aman {}".format(a,b,c)
# Out:
# 'aman name kumar aman hero'

# %%
#palindrome
a = "xyx"
b = 2002
c = "eye"
d = "nitin"

# %%
s = input("Enter a data for which you would like to check palindrome")
s1 = s[::-1]
if s == s1:
    print("Its same")
else:
    print("Its not a same")
# Out:
# Enter a data for which you would like to check palindrome nitin
# Its same

# %%
l = []

# %%
type(l)
# Out:
# list

# %%
l = ["aman",34,34,45,[23,43]]

# %%
l
# Out:
# ['aman', 34, 34, 45, [23, 43]]

# %%
l[0]
# Out:
# 'aman'

# %%
l[3]
# Out:
# 45

# %%
l
# Out:
# ['aman', 34, 34, 45, [23, 43]]

# %%
l[0:3]
# Out:
# ['aman', 34, 34]

# %%
l[0:4:1]
# Out:
# ['aman', 34, 34, 45]

# %%
l
# Out:
# ['aman', 34, 34, 45, [23, 43]]

# %%
l[5:0:-1]
# Out:
# [[23, 43], 45, 34, 34]

# %%
l[-1:-6:-1]
# Out:
# [[23, 43], 45, 34, 34, 'aman']

# %%
l[::-1]
# Out:
# [[23, 43], 45, 34, 34, 'aman']

# %%
l
# Out:
# ['aman', 34, 34, 45, [23, 43]]

# %%
s = "AMAN"

# %%
l + list(s)
# Out:
# ['aman', 34, 34, 45, [23, 43], 'A', 'M', 'A', 'N']

# %%
list(s)
# Out:
# ['A', 'M', 'A', 'N']

# %%
s = ["sudh"]

# %%
l+s
# Out:
# ['aman', 34, 34, 45, [23, 43], 'sudh']

# %%
type(s)
# Out:
# list

# %%
l+s
# Out:
# ['aman', 34, 34, 45, [23, 43], 'sudh']

# %%
s = "aman"

# %%
l+s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[333], line 1
# ----> 1 l+s
#
# TypeError: can only concatenate list (not "str") to list

# %%
l + list(s)
# Out:
# ['aman', 34, 34, 45, [23, 43], 'a', 'm', 'a', 'n']

# %%
s = ["aman"]

# %%
l+a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[336], line 1
# ----> 1 l+a
#
# TypeError: can only concatenate list (not "str") to list

# %%
l+s
# Out:
# ['aman', 34, 34, 45, [23, 43], 'aman']

# %%
l*2
# Out:
# ['aman', 34, 34, 45, [23, 43], 'aman', 34, 34, 45, [23, 43]]

# %%
l*3
# Out:
# ['aman',
#  34,
#  34,
#  45,
#  [23, 43],
#  'aman',
#  34,
#  34,
#  45,
#  [23, 43],
#  'aman',
#  34,
#  34,
#  45,
#  [23, 43]]

# %%
len(l)
# Out:
# 5

# %%
l[0] = "aman is best"

# %%
l
# Out:
# ['aman is best', 34, 34, 45, [23, 43]]

# %%
"aman" in l
# Out:
# False

# %%
"aman is best" in l
# Out:
# True

# %%
65 in l
# Out:
# False

# %%
"my first name is {a} and last name is {b}".format(a="aman", b = "kumar")
# Out:
# 'my first name is aman and last name is kumar'

# %%
8 and 4
# Out:
# 4

# %%
1 and 0
# Out:
# 0

# %%
1 or 4
# Out:
# 1

# %%
4 or 0
# Out:
# 4

# %%
s = "this is a full stack batch"
for i in range(1,len(s)+1):
    print(s[-i])
# Out:
# h
# c
# t
# a
# b
#
# k
# c
# a
# t
# s
#
# l
# l
# u
# f
#
# a
#
# s
# i
#
# s
# i
# h
# t

# %%
s = "my name is shared, and name of org is ineuron"

# %%
s.find("name")
# Out:
# 3

# %%
a = list(s)

# %%
a
# Out:
# ['m',
#  'y',
#  ' ',
#  'n',
#  'a',
#  'm',
#  'e',
#  ' ',
#  'i',
#  's',
#  ' ',
#  's',
#  'h',
#  'a',
#  'r',
#  'e',
#  'd',
#  ',',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  'n',
#  'a',
#  'm',
#  'e',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  'o',
#  'r',
#  'g',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'i',
#  'n',
#  'e',
#  'u',
#  'r',
#  'o',
#  'n']

# %%
s.split()
# Out:
# ['my', 'name', 'is', 'shared,', 'and', 'name', 'of', 'org', 'is', 'ineuron']

# %%
s
# Out:
# 'my name is shared, and name of org is ineuron'

# %%
s = s.split()

# %%
s
# Out:
# ['my', 'name', 'is', 'shared,', 'and', 'name', 'of', 'org', 'is', 'ineuron']

# %%
s[0]
# Out:
# 'my'
